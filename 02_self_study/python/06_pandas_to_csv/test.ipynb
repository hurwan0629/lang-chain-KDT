# %%
import pandas as pd

df_users = pd.DataFrame({
    "user_id": [1, 2, 3],
    "name": ["김철수", "이영희", "박민수"],
    "age": [25, 30, 28]
})

df_orders = pd.DataFrame({
    "order_id": [101, 102, 103],
    "user_id": [1, 2, 1],
    "product": ["노트북", "마우스", "키보드"],
    "price": [1200000, 30000, 80000]
})

df_payments = pd.DataFrame({
    "payment_id": [1001, 1002, 1003],
    "order_id": [101, 102, 103],
    "method": ["card", "bank", "card"],
    "status": ["paid", "paid", "cancelled"]
})

# %%
df_users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  3 non-null      int64
#  1   name     3 non-null      str
#  2   age      3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  3 non-null      int64
#  1   user_id   3 non-null      int64
#  2   product   3 non-null      str
#  3   price     3 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 228.0 bytes

# %%
df_payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   payment_id  3 non-null      int64
#  1   order_id    3 non-null      int64
#  2   method      3 non-null      str
#  3   status      3 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 228.0 bytes

# %%
from pathlib import Path
savepath = Path() / "sample.xlsx"
with pd.ExcelWriter(savepath, engine="openpyxl") as writer:
  df_orders.to_excel(writer, sheet_name="orders", index=False)
  df_payments.to_excel(writer, sheet_name="payments", index=False)
  df_users.to_excel(writer, sheet_name="users", index=False)
