# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

import pandas as pd
import time

# %%
url = "https://www.smart.ac.kr/"

options = Options()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(options=options)
driver.get(url)

wait = WebDriverWait(driver, 5)
actions = ActionChains(driver)

time.sleep(0.5)


# close_btn = wait.until(
#   EC.element_to_be_clickable(
#     (By.CSS_SELECTOR, "a.pop-close()")
#   )
# )

driver.execute_script("exit()")

time.sleep(1)


actions.scroll_by_amount(0, 3000).perform()

time.sleep(0.5)

# news_slider = wait.until(
#     EC.presence_of_all_elements_located(
#       (By.CSS_SELECTOR, 'div.news-card')
#     )
# )

thing = wait.until(
    EC.visibility_of_any_elements_located(
        (By.CSS_SELECTOR, "div.swiper-slide.swiper-slide-active")
    )
)
print(list(map(lambda t: t.get_attribute("innerHTML"), thing)))

actions.move_to_element(thing[0]).pause(3).click().perform()


# for i in range(3):
#     news_slider = wait.until(
#         EC.visibility_of_element_located(
#             (By.CSS_SELECTOR, "section.news-section > div.inner")
#         )
#     )

#     print(news_slider.get_attribute("innerHTML"))

#     actions.move_to_element(news_slider) \
#       .click_and_hold() \
#       .pause(0.2)\
#       .move_by_offset(-500, 0)\
#       .pause(0.2)\
#       .release()\
#       .perform()



    # time.sleep(0.5)

# print(list(map(lambda x: x.get_attribute("innerHTML"), news_slider)))

# print(news_slider.get_attribute("innerHTML"))
# for i in range(3):
#   time.sleep(0.5)
#   actions.drag_and_drop_by_offset(news_slider, -10, 0).release().perform()
# Out:
# ['\n\t\t\t\t\t\t\t\t\t<div class="main-visual__slide" style="background:url(/FileData/Banner/461/461_banner.jpg) repeat-x center top; cursor:pointer;" onclick="location.href=\'https://www.smart.ac.kr/Main/Menu2_lecture/reg_list.asp?hakwi_gubun=1&amp;cdc_code1=&amp;cdc_code2=&amp;searchname=&amp;jun_code=&amp;t_focus=1-1&amp;cs_season=2026-L2-3\'" title="26년 2학기 3기수(7/1개강) 모집 안내 자세한 내용은 학습지원센터 전화번호 1600-0454로 문의해주세요.">\n\t\t\t\t\t\t\t\t\t\t\t<div class="main-visual__content">\n\t\t\t\t\t\t\t\t\t\t\t\t\t<!--p class="main-visual__sub">선착순 마감! 2026학년도 1월 <strong>(2026년 1학기 3차)</strong></p>\n\t\t\t\t\t\t\t\t\t\t\t\t\t<h2 class="main-visual__title">1월 1일 개강</h2>\n\t\t\t\t\t\t\t\t\t\t\t\t\t<div class="main-visual__info">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<p>모집마감 : 2026.01.06(화) 23시까지</p>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<p>사회복지학, 컴퓨터공학, 전기공학, 재난관리, 평생교육사, 경영학, 아동학 과목 보유</p>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<p>모바일 수강 가능</p>\n\t\t\t\t\t\t\t\t\t\t\t\t\t</div-->\n\t\t\t\t\t\t\t\t\t\t\t</div>\n\t\t\t\t
# ...
