# %% [markdown]
# # SVC
# `Support Vector Classifier`
#
# 데이터를 분류할 때 클래스 사이의 경계선을 최대한 여유있게 찾는 모델

# %%
import pandas as pd

wine = pd.read_csv('https://raw.githubusercontent.com/rickiepark/hg-mldl/master/wine.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
  wine[['alcohol', 'sugar', 'pH']], wine['class'],
  test_size=0.2,
  random_state=42
)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

pipe = make_pipeline(
  StandardScaler(),
  SVC()
)

params = {
  "svc__C": [0.1, 1, 10],
  "svc__gamma": ["scale", 0.1, 1],
  "svc__kernel": ["rbf", "linear", "poly"]
}

grid = GridSearchCV(pipe, params, cv=5)
grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_score_)
print(grid.score(X_test, y_test))
# Out:
# {'svc__C': 10, 'svc__gamma': 1, 'svc__kernel': 'rbf'}
# 0.860497334715333
# 0.8546153846153847

# %%
ss = StandardScaler()

X_train_scaled = ss.fit_transform(X_train)

svc = SVC(C=0.1, gamma="scale", kernel="rbf")

svc.fit(X_train_scaled, y_train)
svc.score(ss.transform(X_test), y_test)
# Out:
# 0.7953846153846154
