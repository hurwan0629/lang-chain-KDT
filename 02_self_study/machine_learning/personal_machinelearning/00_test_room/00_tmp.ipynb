# %% [markdown]
# # UCI MPG 데이터 표준편차 보고싶어서 만든 페이지

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

data = fetch_ucirepo(id=9)

X = pd.DataFrame(data.data.features)
y = pd.DataFrame(data.data.targets)

X, y
# Out:
# (     displacement  cylinders  horsepower  ...  acceleration  model_year  origin
#  0           307.0          8       130.0  ...          12.0          70       1
#  1           350.0          8       165.0  ...          11.5          70       1
#  2           318.0          8       150.0  ...          11.0          70       1
#  3           304.0          8       150.0  ...          12.0          70       1
#  4           302.0          8       140.0  ...          10.5          70       1
#  ..            ...        ...         ...  ...           ...         ...     ...
#  393         140.0          4        86.0  ...          15.6          82       1
#  394          97.0          4        52.0  ...          24.6          82       2
#  395         135.0          4        84.0  ...          11.6          82       1
#  396         120.0          4        79.0  ...          18.6          82       1
#  397         119.0          4        82.0  ...          19.4          82       1
#
#  [398 rows x 7 columns],
#        mpg
#  0    18.0
#  1    15.0
#  2    18.0
#  3    16.0
#  4    17.0
#  ..    ...
#  393  27.0
#  394  44.0
#  395  32.0
#  396  28.0
#  397  31.0
#
#  [398 rows x 1 columns])

# %%
X.describe()
# Out:
#        displacement   cylinders  ...  model_year      origin
# count    398.000000  398.000000  ...  398.000000  398.000000
# mean     193.425879    5.454774  ...   76.010050    1.572864
# std      104.269838    1.701004  ...    3.697627    0.802055
# min       68.000000    3.000000  ...   70.000000    1.000000
# 25%      104.250000    4.000000  ...   73.000000    1.000000
# 50%      148.500000    4.000000  ...   76.000000    1.000000
# 75%      262.000000    8.000000  ...   79.000000    2.000000
# max      455.000000    8.000000  ...   82.000000    3.000000
#
# [8 rows x 7 columns]

# %%
y.describe()
# Out:
#               mpg
# count  398.000000
# mean    23.514573
# std      7.815984
# min      9.000000
# 25%     17.500000
# 50%     23.000000
# 75%     29.000000
# max     46.600000

# %%
import matplotlib.pyplot as plt

X.hist(figsize=(12, 8), bins=10) # bins는 막대 (나누는 개수)
plt.tight_layout()
plt.show()
