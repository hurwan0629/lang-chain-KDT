# %%
import numpy as np

X, Y = (np.linspace(-3, 3, 21), np.linspace(-3, 3, 21))

kernel = np.exp(-(X**2+Y**2) / 20)
kernel
# Out:
# array([0.40656966, 0.48239114, 0.56214245, 0.64339271, 0.72325024,
#        0.79851622, 0.86588775, 0.92219369, 0.96464029, 0.99104038,
#        1.        , 0.99104038, 0.96464029, 0.92219369, 0.86588775,
#        0.79851622, 0.72325024, 0.64339271, 0.56214245, 0.48239114,
#        0.40656966])
