# %%
import torch

x = torch.tensor([
    [1, 2, 3],
    [4, 5, 6]
])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
type(x.shape)
# Out:
# torch.Size

# %%
x.shape.count(12)
# Out:
# 0

# %%
isinstance(x.shape, torch.Tensor)
# Out:
# False

# %%
x.flatten()
# Out:
# tensor([1, 2, 3, 4, 5, 6])

# %%
x.dtype
# Out:
# torch.int64

# %%
x[0]
# Out:
# tensor([1, 2, 3])

# %%
x[0, 0].item()
# Out:
# 1

# %%
x[0, 0]
# Out:
# tensor(1)

# %%
type(x[0])
# Out:
# torch.Tensor

# %%
x.flatten()
# Out:
# tensor([1, 2, 3, 4, 5, 6])

# %%
x.flatten().unsqueeze(0).shape
# Out:
# torch.Size([1, 6])

# %%
x.flatten().unsqueeze(0).unsqueeze(2).shape
# Out:
# torch.Size([1, 6, 1])

# %%
x.flatten().unsqueeze(0).unsqueeze(2)
# Out:
# tensor([[[1],
#          [2],
#          [3],
#          [4],
#          [5],
#          [6]]])

# %%
x = torch.tensor([
    [
        [
            [11, 12, 13],
            [14, 15, 16],
        ],
        [
            [21, 22, 23],
            [24, 25, 26],
        ]
    ],
    [
        [
            [31, 32, 33],
            [34, 35, 36],
        ],
        [
            [41, 42, 43],
            [44, 45, 46],
        ]
    ]
])

# %%
x.shape
# Out:
# torch.Size([2, 2, 2, 3])

# %%
x.flatten()
# Out:
# tensor([11, 12, 13, 14, 15, 16, 21, 22, 23, 24, 25, 26, 31, 32, 33, 34, 35, 36,
#         41, 42, 43, 44, 45, 46])

# %%
x.squeeze(2).shape
# Out:
# torch.Size([2, 2, 2, 3])

# %%
x
# Out:
# tensor([[[[11, 12, 13],
#           [14, 15, 16]],
#
#          [[21, 22, 23],
#           [24, 25, 26]]],
#
#
#         [[[31, 32, 33],
#           [34, 35, 36]],
#
#          [[41, 42, 43],
#           [44, 45, 46]]]])

# %%
x.unsqueeze(3)
# Out:
# tensor([[[[[11, 12, 13]],
#
#           [[14, 15, 16]]],
#
#
#          [[[21, 22, 23]],
#
#           [[24, 25, 26]]]],
#
#
#
#         [[[[31, 32, 33]],
#
#           [[34, 35, 36]]],
#
#
#          [[[41, 42, 43]],
#
#           [[44, 45, 46]]]]])

# %%
x.squeeze(([1])).shape
# Out:
# torch.Size([2, 2, 2, 3])

# %%
x = torch.tensor([
    [1, 2, 3],
    [4, 5, 6]
])

y = torch.tensor([
    [3, 4, 5]
])

x * y
# Out:
# tensor([[ 3,  8, 15],
#         [12, 20, 30]])

# %%
try:
    x @ y
except Exception as e:
    print(e)
# Out:
# mat1 and mat2 shapes cannot be multiplied (2x3 and 1x3)

# %%
y @ x.T
# Out:
# tensor([[26, 62]])

# %%
x + y
# Out:
# tensor([[ 4,  6,  8],
#         [ 7,  9, 11]])

# %%
x / 4
# Out:
# tensor([[0.2500, 0.5000, 0.7500],
#         [1.0000, 1.2500, 1.5000]])

# %%
type(x + 2), x + 2
# Out:
# (torch.Tensor,
#  tensor([[3, 4, 5],
#          [6, 7, 8]]))

# %%
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.argmax()
# Out:
# tensor(5)

# %%
x.argmax(dim=1) # 2 예상 -> [2, 2] = 각 행마다의 최대위치
# Out:
# tensor([2, 2])

# %%
z = torch.tensor([
    [
        [1, 5, 3],
        [4, 2, 6],
        # [9, 9, 9]
    ],
    [
        # [9, 9, 9],
        [2, 6, 4],
        [5, 3, 7]
    ]
])

z.argmax(dim=1) # [5, 5]?
# Out:
# tensor([[1, 0, 1],
#         [1, 0, 1]])

# %%
z.argmax(dim=0)
# Out:
# tensor([[1, 1, 1],
#         [1, 1, 1]])

# %%
z.argmax(dim=2)
# Out:
# tensor([[1, 2],
#         [1, 2]])
