# %% [markdown]
# # CNN 수업 복습 응용
# 이번 수업 복습에는 2가지 목적이 있습니다.
# - 수업에서 다룬 코드 템플릿을 따라가면서 보지 않고도 원활하게 구조를 설계하고 코드를 작성할 수 있게 되는 것
# - 함수를 설계하며 파이토치 내부적인 구조 등에 대해서 이해하며 여러 기법 등에 대한 사고를 할 수 있게 되는 것
#
# 수업에서는 다음과 같은 내용을 학습했습니다.
#
# | 영역         | 수업에서 나온 내용               | 코드/객체                                                |
# | ---------- | ------------------------ | ---------------------------------------------------- |
# | 환경         | 난수 고정                    | `random.seed`, `np.random.seed`, `torch.manual_seed` |
# | 파일         | 경로 관리                    | `Path`                                               |
# | 파일         | zip 데이터 압축 해제            | `zipfile.ZipFile`, `extractall()`                    |
# | Dataset    | 폴더 기반 이미지 Dataset        | `datasets.ImageFolder`                               |
# | Dataset    | 클래스 정보                   | `.classes`, `.class_to_idx`, `.targets`              |
# | 전처리        | 여러 변환 묶기                 | `transforms.Compose`                                 |
# | 전처리        | 이미지 크기 통일                | `Resize`                                             |
# | 전처리        | 1채널 변환                   | `Grayscale`                                          |
# | 전처리        | 픽셀 반전                    | `RandomInvert`                                       |
# | 증강         | 이동·회전·크기 변화              | `RandomAffine`                                       |
# | Tensor     | 이미지 → Tensor             | `ToTensor`                                           |
# | Scaling    | `[0,1] → [-1,1]` 근처      | `Normalize`                                          |
# | 데이터 분리     | 클래스별 train/validation 분할 | `.targets`, `np.where`, `shuffle`                    |
# | Dataset    | 일부 index만 사용             | `Subset`                                             |
# | DataLoader | batch 생성                 | `DataLoader`                                         |
# | DataLoader | 데이터 섞기                   | `shuffle`                                            |
# | DataLoader | 로딩 worker                | `num_workers`                                        |
# | 메모리        | pinned memory            | `pin_memory=True`                                    |
# | Tensor     | CNN 입력 shape             | `[B, C, H, W]`                                       |
# | 시각화        | 이미지 batch 확인             | `matplotlib`, `subplots`                             |
# | CNN        | 합성곱                      | `Conv2d`                                             |
# | CNN        | 채널 정규화                   | `BatchNorm2d`                                        |
# | CNN        | 활성화                      | `ReLU(inplace=True)`                                 |
# | CNN        | 공간 크기 축소                 | `MaxPool2d`                                          |
# | CNN        | 출력 크기 강제 통일              | `AdaptiveAvgPool2d`                                  |
# | CNN        | 벡터화                      | `Flatten`                                            |
# | 규제         | 일부 activation 제거         | `Dropout`                                            |
# | 분류         | FC 출력                    | `Linear`                                             |
# | 모델         | Layer 묶기                 | `nn.Sequential`                                      |
# | 장치         | CUDA/MPS/CPU 선택          | `torch.cuda`, `torch.backends.mps`                   |
# | Loss       | 다중 분류 손실                 | `CrossEntropyLoss`                                   |
# | Optimizer  | Adam + weight decay      | `AdamW`                                              |
# | Scheduler  | 성능 정체 시 LR 감소            | `ReduceLROnPlateau`                                  |
# | 학습모드       | train/eval 전환            | `model.train()`, `model.eval()`                      |
# | Autograd   | 학습 시 grad 활성화            | `torch.enable_grad()`                                |
# | 추론         | grad/추론 bookkeeping 제거   | `torch.inference_mode()`                             |
# | CPU→GPU    | Tensor 장치 이동             | `.to(device)`                                        |
# | 전송 최적화     | non-blocking 전송 요청       | `non_blocking=True`                                  |
# | gradient   | gradient 초기화 최적화         | `zero_grad(set_to_none=True)`                        |
# | 역전파        | gradient 계산              | `loss.backward()`                                    |
# | 업데이트       | parameter 수정             | `optimizer.step()`                                   |
# | 평가         | batch accuracy 누적        | `argmax`, `.sum()`                                   |
# | 평가         | sample 수 기반 loss 평균      | `loss.item() * batch_size`                           |
# | 학습관리       | loss/accuracy 기록         | `history`                                            |
# | 학습관리       | best validation loss     | `best_val_loss`                                      |
# | 학습관리       | Early Stopping 준비        | `patience`, `wait`                                   |
# | 저장         | 모델 저장 경로                 | `.pth`                                               |

# %% [markdown]
# # 이번에 작업할 주제
# 이번에는 **위성사진 토지 종류 분류** 데이터셋을 이용하여
#
# EuroSAT에서 제공해주는 `forest`, `river`, `residential` 등을 분류할 수 있게 하려고 합니다.
#
# 이를 통해서 색/질감/공간 패턴을 어떻게 보는지 확인하며 프레임워크 구조를 이해하는 것을 목표로 하겠습니다.

# %%
from operator import contains

import torch
from torchvision import datasets, transforms
from collections import Counter
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from operator import contains
#       2
#       3 import torch
# ----> 4 from torchvision import datasets, transforms
#       5 from collections import Counter
#       6
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import (
#       9     _autograd_registrations,
#      10     _meta_registrations,
#      11     datasets,
#      12     io,
#      13     models,
#      14     ops,
#      15     transforms,
#      16     utils,
#      17 )  # usort:skip
#      19 try:
#      20     from .version import __version__  # noqa: F401
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\models\convnext.py:9
#       6 from torch import nn, Tensor
#       7 from torch.nn import functional as F
# ----> 9 from ..ops.misc import Conv2dNormActivation, Permute
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: list[Tensor]) -> Tensor:
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     bytecode_debugger,
#      16     config,
#      17     convert_frame,
#      18     eval_frame,
#      19     functional_export,
#      20     resume_execution,
#      21 )
#      22 from .backends.registry import list_backends, lookup_backend, register_backend
#      23 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\aot_compile.py:17
#      15 import torch
#      16 import torch.fx
# ---> 17 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      18 from torch._dynamo.graph_utils import _graph_device_type
#      19 from torch._dynamo.package import SystemInfo
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\convert_frame.py:62
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:62
#      59 from torch.fx.experimental.symbolic_shapes import guard_bool
#      60 from torch.utils._functools import cache_method
# ---> 62 from . import (
#      63     config,
#      64     exc,
#      65     graph_break_hints,
#      66     logging as torchdynamo_logging,
#      67     trace_rules,
#      68     variables,
#      69 )
#      70 from .bytecode_analysis import (
#      71     get_indexof,
#      72     JUMP_OPNAMES,
#      73     livevars_analysis,
#      74     propagate_line_nums,
#      75 )
#      76 from .bytecode_transformation import (
#      77     cleaned_instructions,
#      78     create_binary_slice,
#    (...)     92     unique_id,
#      93 )
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\trace_rules.py:60
#      52 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      53 from .utils import (
#      54     getfile,
#      55     hashable,
#    (...)     58     unwrap_if_wrapper,
#      59 )
# ---> 60 from .variables import (
#      61     BuiltinVariable,
#      62     DictBuiltinVariable,
#      63     FunctionalCallVariable,
#      64     FunctorchHigherOrderVariable,
#      65     GetAttrBuiltinVariable,
#      66     HasAttrBuiltinVariable,
#      67     InspectSignatureVariable,
#      68     IterBuiltinVariable,
#      69     ListBuiltinVariable,
#      70     LocalGeneratorFunctionVariable,
#      71     LocalGeneratorObjectVariable,
#      72     NestedUserFunctionVariable,
#      73     PolyfilledFunctionVariable,
#      74     PyTreeGetNodeTypeFunctionVariable,
#      75     PyTreeTreeIsLeafFunctionVariable,
#      76     ReparametrizeModuleCallVariable,
#      77     SetAttrBuiltinVariable,
#      78     SkipFunctionVariable,
#      79     SparseTensorCreationSkipVariable,
#      80     TorchInGraphFunctionVariable,
#      81     UserFunctionVariable,
#      82     UserMethodVariable,
#      83 )
#      84 from .variables.base import VariableTracker
#      87 np: types.ModuleType | None = None
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import (
#      21     BaseBuiltinVariable,
#      22     BuiltinVariable,
#    (...)     28     SetAttrBuiltinVariable,
#      29 )
#      30 from .constant import ConstantVariable
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\base.py:1943
#    1937         for vt_cls in vt_classes:
#    1938             print(
#    1939                 f"{py_type.__module__}.{py_type.__qualname__:30s} -> {vt_cls.__name__}"
#    1940             )
# -> 1943 from . import builder
#    1944 from .lazy import LazyVariableTracker
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\builder.py:126
#     118 from ..guards import GuardBuilder, install_guard, make_dupe_guard
#     119 from ..pgo import (
#     120     auto_dynamic,
#     121     auto_unset,
#    (...)    124     process_automatic_dynamic,
#     125 )
# --> 126 from ..side_effects import SideEffects
#     127 from ..source import (
#     128     AttrProxySource,
#     129     AttrSource,
#    (...)    160     UnspecializedParamBufferSource,
#     161 )
#     162 from ..utils import (
#     163     _extract_tensor_dict,
#     164     build_checkpoint_variable,
#    (...)    196     wrap_fake_exception,
#     197 )
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\side_effects.py:38
#      36 import torch
#      37 import torch.nn
# ---> 38 from torch._dynamo.variables.misc import AutogradFunctionContextVariable
#      39 from torch.utils._ordered_set import OrderedSet
#      40 from torch.utils._pytree import is_structseq_class
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\misc.py:40
#      38 import torch.utils._pytree as pytree
#      39 from torch._dynamo.variables.base import MutationType
# ---> 40 from torch._dynamo.variables.lists import TupleVariable
#      41 from torch._guards import Source
#      43 from .. import config, graph_break_hints, trace_rules, variables
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\lists.py:51
#      49 from .base import AsPythonConstantNotImplementedError, ValueMutationNew, VariableTracker
#      50 from .constant import ConstantVariable
# ---> 51 from .functions import UserFunctionVariable
#      52 from .iter import IteratorVariable
#      53 from .object_protocol import (
#      54     pyindex_check,
#      55     type_implements_nb_index,
#      56     validate_sequence_index,
#      57     vt_is_iterable,
#      58 )
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\functions.py:98
#      91 from .base import (
#      92     AsPythonConstantNotImplementedError,
#      93     AttributeMutationNew,
#      94     ValueMutationNew,
#      95     VariableTracker,
#      96 )
#      97 from .constant import ConstantVariable
# ---> 98 from .user_defined import UserDefinedObjectVariable
#     101 try:
#     102     from torch.distributed.fsdp._fully_shard import _fsdp_param_group
#
# File C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\.venv\Lib\site-packages\torch\_dynamo\variables\user_defined.py:112
#      76 from ..utils import (
#      77     base_exception_methods,
#      78     check_constant_args,
#    (...)    101     unpatched_nn_module_getattr,
#     102 )
#     103 from .base import (
#     104     _RICHCOMPARE_OPS,
#     105     AsPythonConstantNotImplementedError,
#    (...)    110     VariableTracker,
#     111 )
# --> 112 from .dicts import ConstDictVariable, pydict_check
#     113 from .hashable import HashableTracker
#     114 from .object_protocol import is_nb_not_implemented, type_implements_nb_slot
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1532, in PathFinder.find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1506, in PathFinder._get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1638, in FileFinder.find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#     159 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap_external>:154, in _path_is_mode_type(path, mode)
#     150 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
import numpy as np
import pprint

from sklearn.model_selection import train_test_split

# %%
print(torch.__version__)
print(torch.cuda.is_available())

# %%
# torchvision.datasets를 이용하여
# EuroSAT 데이터셋을 불러옵니다.
dataset = datasets.EuroSAT(
    # 인터프리터가 현재 작업중인 경로 기준으로 계산되는 저장 경로입니다.
    root="./data",
    # 로컬에 데이터가 없으면 다운을 받겠다는 의미이며
    # 메모리에 저장을 하지 않는다는 것입니다.
    download=True
)

# %%
print(type(dataset))
print(isinstance(dataset, torch.utils.data.Dataset))
print(dataset.classes)
print(dataset.class_to_idx)

# %% [markdown]
# # 데이터셋 살펴보기
# 현재 받은 데이터셋은 `torchvision.datasets.eurosat.EuroSAT` 타입으로 `torch.utils.data.Dataset`을 상속한 클래스입니다.
#
# 이는 `__getitem__`을 통해 `tuple(PIL.Image.Image, int)` 데이터를  받을 수 있으며 첫번째 인자는 이미지 객체로 나타납니다. 해당 데이터의 사이즈를 찍으면 `(64, 64)`임을 확인할 수 있습니다.

# %%
image, label = dataset[0]

print(type(image))
print(isinstance(image, torch.Tensor))
print(type(label))
print(image.size)

# %% [markdown]
# # PIL 이미지를 CNN이 받을 수 있는 Tensor로 바꾸고, 변환 전후로 직접 확인하기
#
# 해당 데이터를 받는 시점에 Dataset 클래스의 `__getitem__`의 transform을 등록하게 하여 `ToTensor()`을 적용시켜 줍니다.
#
# 여기에서 ToTensor은 Image를 Tensor 타입으로 변환하는 것 이외에도 0~255 이미지 픽셀값을 0.0 ~ 1.0 범위로 float32 Tensor로 변환시켜줍니다.
#
# 또한 데이터 하나의 `shape=(C, H, W)` 형태로 변환해주게 됩니다.

# %%
# 데이터를 Tensor 타입으로 바꾸며 정규화(standardization) 해주는 callable 객체 생성
transform = transforms.Compose([
    transforms.ToTensor(),
])

dataset = datasets.EuroSAT(
    root="./data",
    download=False,
    # 데이터에서 __getitem__을 시점에 transform을 적용하게 만들기
    transform=transform
)

# 2만 7천개의 데이터셋
print(len(dataset))

# %%
image, label = dataset[0]

print(type(image))
print(isinstance(image, torch.Tensor))

print(image.shape)
print(image.dtype)

print(image.min())
print(image.max())

print("\n", image)

# %%
print("전체 데이터 수:", len(dataset))
print("클래스 수:", len(dataset.classes))
print("클래스: ", len(dataset.classes))
print("매핑:", dataset.class_to_idx)

# %% [markdown]
# EuroSAT는 ImageFolder 계열이기 때문에 targets에 각 이미지의 정답 인덱스가 들어있습니다.

# %%
print(type(dataset.targets))
print(dataset.targets[:10])
print(dataset.targets[4500:4510])

# %%
# Counter 타입으로 dataset.targets - python list를 변환
class_counts = Counter(dataset.targets)

pprint.pprint(class_counts)

# %%
eurosat_idx_to_class = {}

print("class_idx type:", type(list(dataset.class_to_idx)[0]))
print("class_name type:", type(list(dataset.class_to_idx)[1]))

for class_name,class_idx in dataset.class_to_idx.items():
    eurosat_idx_to_class[class_idx] = class_name

# %% [markdown]
# # 층화 검증 데이터 분할하기
# 해당 데이터는 거의 3000~2000개로 적절한 비율을 유지한다고 판단되어 데이터를 비율대로 분리하겠습니다.
#
# 이때 사용하는 라이브러리는 skleanr.model_selection의 train_test_split입니다.

# %%
# 데이터를 그대로 메모리에 올릴 수 없기 때문에 인덱스를 기준으로 나눠줍니다.
indices = np.arange(len(dataset))

print(indices[:10])
print(len(indices))

# %%
dataset

# %%
# DatasetFolder 타입을 ndarray 형태로 변환하기 ->
targets = np.array(dataset.targets)

print(targets.shape)

train_idx, test_idx = train_test_split(
    # 해당 데이터에는 `indexable` 자료구조가 들어갈 수 있어서 ndarray도 들어갈 수 있습니다.
    indices,
    test_size=0.3,
    random_state=42,
    stratify=targets
)

train_idx, val_idx = train_test_split(
    train_idx,
    test_size=0.3,
    random_state=42,
    stratify=targets[train_idx]
)

len(train_idx), len(val_idx), len(test_idx)

# %% [markdown]
# # Subset
# Subset는 torch.utils.data.Subset 위치에 존재하며 첫번째 인자로 Dataset 타입을 받으며 두번째 인자로 해당 데이터의 인덱스 위치 리스트를 받아서 데이터 래퍼를 생성해줍니다.
#
# 복사 방식이 아니며 주소를 참조하여 사용하게 됩니다.

# %%
from torch.utils.data import Subset

# Subset 만들기
train_dataset = Subset(dataset, train_idx)
test_dataset = Subset(dataset, test_idx)

# %%
print(train_dataset)
print(len(train_dataset))
print(len(test_dataset))
# Subset끼리의 합연산이 성립한다.
print(len(train_dataset + test_dataset))
print(len(train_dataset[0]))
print(type(train_dataset[0][0]))
print(type(train_dataset[0][1]))
print(train_dataset[0][0].shape)

# %%
# 원본 데이터셋
print(train_dataset.dataset)
print(train_dataset.dataset is dataset)
# 실제로 사용하는 식별자들
# 실제로 indices[0] = 0이 아닐 수 있습니다.
# train_dataset[0] = train_dataset.dataset[train_dataset.indices[0]] 입니다. (개념상)
print(train_dataset.indices[:10])

# %%
# transform 파이프라인 만들어주기
train_transform = transforms.Compose([
    # 좌우 대칭
    transforms.RandomHorizontalFlip(),
    # 수직 대칭
    transforms.RandomVerticalFlip(),
    # 정규화 + 텐서화
    transforms.ToTensor()
])

# 테스트할 때에는 그대로 데이터 형태만 Tensor로 바꿔주면 됨
eval_transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
train_full = datasets.EuroSAT(
    root="./data",
    download=False,
    transform=train_transform
)

eval_full = datasets.EuroSAT(
    root="./data",
    download=False,
    transform=eval_transform
)

# %%
train_dataset = Subset(train_full, train_idx)
val_dataset = Subset(eval_full, val_idx)
test_dataset = Subset(eval_full, test_idx)

# %%
# transform을 거쳐서 데이터가 변환되어 잘못 나올 수 있음
flags = []
while len(flags) < 2:
    img1, label1 = train_dataset[0]
    img2, label2 = train_dataset[0]
    flag =torch.equal(img1, img2)
    print(flag)
    if flags.__contains__(flag):
        continue
    else:
        flags.append(flag)

# %%
flags = []

for i in range(100):
    img1, _ = val_dataset[0]
    img2, _ = val_dataset[0]

    flag = torch.equal(img1, img2)

    if not flags.__contains__(flag):
        flags.append(flag)
        print(f"{flag} appended", flags)

    if len(flags) > 1:
        print("both occured")
        break

print(flags)

# %%
print()
