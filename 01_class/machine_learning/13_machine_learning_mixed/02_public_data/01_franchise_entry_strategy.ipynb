# %% [markdown]
# # **1. 서울 스타벅스 주변 소상공인 / 커피 프랜차이즈 입점 전략 분석**
#
# ## 분석 목표
#
# 1. 스타벅스 주변에 커피전문점이 많이 분포하는가?
# 2. 특정 프렌차이즈는 스타벅스와 가까운 곳에 입점하는 경향이 있는가?
# 3. 어느 자치구에서 스타벅스와 프렌차이즈가 함께 밀집되어있는가?
# 4. 거리 구간별, 브랜드별, 자치구별 시각화를 통해 어떤 결론을 내릴 수 있는가?

# %% [markdown]
# ### 2. 분석 주의점
# - 이 분석은 위치 데이터 기반의 상관관계 분석임
#     - 상관관계: 두 현상이 함께 변하는 관계를 말함
#     - 인과관계: 한 현상이 다른 현상의 원인이 되는 것을 말함
# - 소상공인 데이터에 개업일 또는 입점 순서가 없어서 "스타벅스가 먼저 생기고 주변에 다른 가게가 생겼다."는 인과관계도 증명할 수 없음

# %%
from pathlib import Path

import pandas as pd
import re
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
BASE_DIR = Path.cwd()
print("현재 작업 폴더:", BASE_DIR)
DATA_DIR = BASE_DIR / "data"
print("데이터 폴더:", DATA_DIR)
OUTPUT_DIR = BASE_DIR / "output"
OUTPUT_DIR.mkdir(exist_ok=True)
print("결과 저장 폴더: ", OUTPUT_DIR)
# Out:
# 현재 작업 폴더: C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\python\13_machine_learning\02_public_data
# 데이터 폴더: C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\python\13_machine_learning\02_public_data\data
# 결과 저장 폴더:  C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\python\13_machine_learning\02_public_data\output

# %%
STARBUCKS_FILE = "starbucks_seoul.csv"
SMALL_BIZ_FILE = "소상공인시장진흥공단_상가(상권)정보_서울_202603.csv"
STARBUCKS_PATH = DATA_DIR / STARBUCKS_FILE
SMALL_BIZ_PATH = DATA_DIR / SMALL_BIZ_FILE

print(STARBUCKS_PATH)
print(SMALL_BIZ_PATH)
# Out:
# C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\python\13_machine_learning\02_public_data\data\starbucks_seoul.csv
# C:\LANG_CHAIN_2026\2026-05-19_KDT_lang_chain\workspace\python\13_machine_learning\02_public_data\data\소상공인시장진흥공단_상가(상권)정보_서울_202603.csv

# %%
df_starbucks_raw = pd.read_csv(STARBUCKS_PATH, encoding="utf-8")
df_starbucks_raw.head()
# Out:
#        store                        addr        lat         lng
# 0  역삼아레나빌딩       서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1   논현역사거리      서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2  신사역성일빌딩      서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3   국기원사거리      서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4   대치재경빌딩    서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583

# %%
df_raw = pd.read_csv(SMALL_BIZ_PATH, encoding="utf-8", low_memory=False)
df_raw.head()
# Out:
#                  상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800800619  참편한공인중개사사무소  NaN        L1      부동산      L102
# 1  MA010120220804265295      60계치킨암사  선사점        I2       음식      I210
# 2  MA010120220809658173       성심인력공사  NaN        N1  시설관리·임대      N104
# 3  MA010120220808205276          칸토빈  NaN        I2       음식      I212
# 4  MA010120220804370987      까치노래연습장  NaN        R1   예술·스포츠      R104
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010100109270035014757
# 1    기타 간이    I21006          치킨   I56193  ...  1174010700105020004015779
# 2    고용 알선    N10401      고용 알선업   N75110  ...  1117010700100430059022991
# 3    비알코올     I21201          카페   I56221  ...  1150010800200200002002536
# 4   유원지·오락    R10407         노래방   R91223  ...  1135010500101690179002482
#
#        건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0      NaN   서울특별시 서초구 방배로19길 25  137843  6682  NaN    1  NaN  126.993691
# 1  암사동정웅빌딩     서울특별시 강동구 상암로3길 8  134877  5241  NaN    1  NaN  127.126859
# 2      NaN    서울특별시 용산구 한강대로 385  140821  4320  NaN  NaN  NaN  126.972240
# 3    공항시장역     서울특별시 강서구 방화동로 30  157240  7619  NaN    1  NaN  126.810493
# 4      NaN  서울특별시 노원구 한글비석로23길 2  139815  1682  NaN  NaN  NaN  127.071218
#
#           위도
# 0  37.484844
# 1  37.550810
# 2  37.552803
# 3  37.563548
# 4  37.660715
#
# [5 rows x 39 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 537489 entries, 0 to 537488
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     537489 non-null  str
#  1   상호명        537489 non-null  str
#  2   지점명        47001 non-null   str
#  3   상권업종대분류코드  537489 non-null  str
#  4   상권업종대분류명   537489 non-null  str
#  5   상권업종중분류코드  537489 non-null  str
#  6   상권업종중분류명   537489 non-null  str
#  7   상권업종소분류코드  537489 non-null  str
#  8   상권업종소분류명   537489 non-null  str
#  9   표준산업분류코드   537291 non-null  str
#  10  표준산업분류명    537291 non-null  str
#  11  시도코드       537489 non-null  int64
#  12  시도명        537489 non-null  str
#  13  시군구코드      537489 non-null  int64
#  14  시군구명       537489 non-null  str
#  15  행정동코드      537489 non-null  int64
#  16  행정동명       537489 non-null  str
#  17  법정동코드      537489 non-null  int64
#  18  법정동명       537489 non-null  str
#  19  지번코드       537489 non-null  int64
#  20  대지구분코드     537489 non-null  int64
#  21  대지구분명      537489 non-null  str
#  22  지번본번지      537465 non-null  float64
#  23  지번부번지      443007 non-null  float64
#  24  지번주소       537489 non-null  str
#  25  도로명코드      537489 non-null  int64
#  26  도로명        537489 non-null  str
#  27  건물본번지      537487 non-null  float64
#  28  건물부번지      69643 non-null   float64
#  29  건물관리번호     535217 non-null  object
#  30  건물명        250658 non-null  str
#  31  도로명주소      537489 non-null  str
#  32  구우편번호      537489 non-null  int64
#  33  신우편번호      537489 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        336835 non-null  str
#  36  호정보        0 non-null       float64
#  37  경도         537489 non-null  float64
#  38  위도         537489 non-null  float64
# dtypes: float64(8), int64(9), object(1), str(21)
# memory usage: 159.9+ MB

# %%
print("스타벅스 원본:", df_starbucks_raw.shape)
print("소상공인 원본:", df_raw.shape)
# Out:
# 스타벅스 원본: (692, 4)
# 소상공인 원본: (537489, 39)

# %%
df_starbucks = df_starbucks_raw

# %%
if {'지점명', '주소', '위도', '경도'}.issubset(df_starbucks_raw.columns):
    df_starbucks = df_starbucks[['지정명', '주소', '위도', '경도']].copy()
    df_starbucks.columns= ['스타벅스지점명', '스타벅스주소', '스타벅스위도', '스타벅스경도']
elif df_starbucks.shape[1] >= 4:
    df_starbucks = df_starbucks.iloc[:, :4]
    df_starbucks.columns= ['스타벅스지점명', '스타벅스주소', '스타벅스위도', '스타벅스경도']
else:
    raise ValueError("스타벅스 데이터에 최소 4개 컬럼이 필요합니다.")

# %%
df_starbucks
# Out:
#        스타벅스지점명                                 스타벅스주소     스타벅스위도      스타벅스경도
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 687      면목역                  서울특별시 중랑구 면목로 403 (면목동)  37.587880  127.087609
# 688       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 689      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 690      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 691      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [692 rows x 4 columns]

# %%
df_starbucks.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   스타벅스지점명  692 non-null    str
#  1   스타벅스주소   692 non-null    str
#  2   스타벅스위도   692 non-null    float64
#  3   스타벅스경도   692 non-null    float64
# dtypes: float64(2), str(2)
# memory usage: 21.8 KB

# %%
df_starbucks['스타벅스위도'] = pd.to_numeric(df_starbucks['스타벅스위도'], errors='coerce') # coerce는 강요하다라는 뜻으로 에러가 나도 NaN 으로 변환해달라는 요
# 청
df_starbucks['스타벅스경도'] = pd.to_numeric(df_starbucks['스타벅스경도'], errors='coerce')
# 만약 NaN이 존재한다면... 그 행 삭제 / drop_duplicates 는 중복된 행을 삭제한다는 의미
df_starbucks = df_starbucks.dropna(subset=['스타벅스위도', '스타벅스경도'], axis=0).drop_duplicates()
df_starbucks.shape
# Out:
# (692, 4)

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 537489 entries, 0 to 537488
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     537489 non-null  str
#  1   상호명        537489 non-null  str
#  2   지점명        47001 non-null   str
#  3   상권업종대분류코드  537489 non-null  str
#  4   상권업종대분류명   537489 non-null  str
#  5   상권업종중분류코드  537489 non-null  str
#  6   상권업종중분류명   537489 non-null  str
#  7   상권업종소분류코드  537489 non-null  str
#  8   상권업종소분류명   537489 non-null  str
#  9   표준산업분류코드   537291 non-null  str
#  10  표준산업분류명    537291 non-null  str
#  11  시도코드       537489 non-null  int64
#  12  시도명        537489 non-null  str
#  13  시군구코드      537489 non-null  int64
#  14  시군구명       537489 non-null  str
#  15  행정동코드      537489 non-null  int64
#  16  행정동명       537489 non-null  str
#  17  법정동코드      537489 non-null  int64
#  18  법정동명       537489 non-null  str
#  19  지번코드       537489 non-null  int64
#  20  대지구분코드     537489 non-null  int64
#  21  대지구분명      537489 non-null  str
#  22  지번본번지      537465 non-null  float64
#  23  지번부번지      443007 non-null  float64
#  24  지번주소       537489 non-null  str
#  25  도로명코드      537489 non-null  int64
#  26  도로명        537489 non-null  str
#  27  건물본번지      537487 non-null  float64
#  28  건물부번지      69643 non-null   float64
#  29  건물관리번호     535217 non-null  object
#  30  건물명        250658 non-null  str
#  31  도로명주소      537489 non-null  str
#  32  구우편번호      537489 non-null  int64
#  33  신우편번호      537489 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        336835 non-null  str
#  36  호정보        0 non-null       float64
#  37  경도         537489 non-null  float64
#  38  위도         537489 non-null  float64
# dtypes: float64(8), int64(9), object(1), str(21)
# memory usage: 159.9+ MB

# %%
def find_col(df, candidates):
    """df를 넣어서 후보에 해당하는 컬럼명 중 하나의 컬럼이 있는지 확인하기. 없으면 KeyError 발생"""
    for col in candidates:
        if col in df.columns:
            return col
    raise KeyError(f"다음 후보 컬럼을 찾을 수 없습니다: {candidates}")

# %%
id_col = find_col(df_raw, ['상가업소번호', '상가업소번호명'])
name_col = find_col(df_raw, ['상호명'])
category_l_col = find_col(df_raw, ['상권업종대분류명', '상권업종대분류코드'])
category_m_col = find_col(df_raw, ['상권업종중분류명', '상권업종중분류코드'])
category_s_col = find_col(df_raw, ['상권업종소분류명', '상권업종소분류코드'])

address_col = find_col(df_raw, ['도로명주소', '지번주소'])
lat_col = find_col(df_raw, ['위도'])
lon_col = find_col(df_raw, ['경도'])

# %%
use_cols = [id_col, name_col, category_l_col, category_m_col, category_s_col, address_col, lat_col, lon_col]
df_store = df_raw[use_cols].copy()
df_store
# Out:
#                       상가업소번호            상호명 상권업종대분류명     상권업종중분류명    상권업종소분류명  \
# 0       MA010120220800800619    참편한공인중개사사무소      부동산      부동산 서비스  부동산 중개/대리업
# 1       MA010120220804265295        60계치킨암사       음식        기타 간이          치킨
# 2       MA010120220809658173         성심인력공사  시설관리·임대        고용 알선      고용 알선업
# 3       MA010120220808205276            칸토빈       음식        비알코올           카페
# 4       MA010120220804370987        까치노래연습장   예술·스포츠       유원지·오락         노래방
# ...                      ...            ...      ...          ...         ...
# 537484  MA0106202601A1319837  더지엘에너지(주)목동지점       소매        연료 소매         주유소
# 537485  MA0106202601A2413483          뷰티에이지    수리·개인        이용·미용         미용실
# 537486  MA0106202601A0824946     리나스 예술의전당점       음식           한식      백반/한정식
# 537487  MA0106202601A1120245      제이라스 스튜디오       소매  섬유·의복·신발 소매  유아용 의류 소매업
# 537488  MA0106202601A0396463           부산어묵       음식           한식      백반/한정식
#
#                          도로명주소         위도          경도
# 0          서울특별시 서초구 방배로19길 25  37.484844  126.993691
# 1            서울특별시 강동구 상암로3길 8  37.550810  127.126859
# 2           서울특별시 용산구 한강대로 385  37.552803  126.972240
# 3            서울특별시 강서구 방화동로 30  37.563548  126.810493
# 4         서울특별시 노원구 한글비석로23길 2  37.660715  127.071218
# ...                        ...        ...         ...
# 537484     서울특별시 양천구 안양천로 1171  37.545315  126.882157
# 537485    서울특별시 강남구 테헤란로30길 31  37.499253  127.040045
# 537486    서울특별시 서초구 남부순환로 2406  37.480338  127.014144
# 537487     서울특별시 중구 남대문시장8길 16  37.559697  126.978315
# 537488  서울특별시 관악구 남부순환로208길 11  37.481605  126.943458
#
# [537489 rows x 8 columns]

# %%
df_store['위도'] = pd.to_numeric(df_store['위도'], errors='coerce')
df_store['경도'] = pd.to_numeric(df_store['경도'], errors='coerce')
df_store = df_store.dropna(subset=['위도', '경도']).drop_duplicates()
df_store.shape
# Out:
# (537489, 8)

# %%
df_store = df_store[
    (df_store['위도'].between(37.0, 38.0))
    &
    (df_store['경도'].between(126.0, 128.0))
]
df_store.shape
# Out:
# (537489, 8)

# %%
df_store.head()
# Out:
#                  상가업소번호          상호명 상권업종대분류명 상권업종중분류명    상권업종소분류명  \
# 0  MA010120220800800619  참편한공인중개사사무소      부동산  부동산 서비스  부동산 중개/대리업
# 1  MA010120220804265295      60계치킨암사       음식    기타 간이          치킨
# 2  MA010120220809658173       성심인력공사  시설관리·임대    고용 알선      고용 알선업
# 3  MA010120220808205276          칸토빈       음식    비알코올           카페
# 4  MA010120220804370987      까치노래연습장   예술·스포츠   유원지·오락         노래방
#
#                   도로명주소         위도          경도
# 0   서울특별시 서초구 방배로19길 25  37.484844  126.993691
# 1     서울특별시 강동구 상암로3길 8  37.550810  127.126859
# 2    서울특별시 용산구 한강대로 385  37.552803  126.972240
# 3     서울특별시 강서구 방화동로 30  37.563548  126.810493
# 4  서울특별시 노원구 한글비석로23길 2  37.660715  127.071218

# %%
coffee_keywords = ['커피', '카페', '까페', 'coffee', 'caffee']
mask_coffee = (df_store['상권업종중분류명'].astype(str).str.contains('커피|카페|음료', na=False)
               | df_store['상권업종소분류명'].astype(str).str.contains('커피|카페|음료', na=False)
               | df_store['상권업종대분류명'].astype(str).str.contains('커피|카페|음료', case=False, na=False)
               )
df_cafe = df_store[mask_coffee].copy()
df_cafe.shape
# Out:
# (24845, 8)

# %%
brand_patterns = {
    '메가커피': r'메가\s*커피|메가\s*엠지씨|메가MGC|메가\s*MGC|MEGA\s*MGC|MEGA\s*COFFEE',
    '컴포즈커피': r'컴포즈\s*커피|COMPOSE\s*COFFEE',
    '빽다방': r'빽다방|PAIK',
    '이디야': r'이디야|EDIYA',
    '투썸플레이스': r'투썸|A\s*TWOSOME|TWOSOME',
    '할리스': r'할리스|HOLLYS',
    '커피빈': r'커피빈|COFFEE\s*BEAN',
    '파스쿠찌': r'파스쿠찌|PASCUCCI',
    '탐앤탐스': r'탐앤탐스|TOM\s*N\s*TOMS',
    '더벤티': r'더벤티|THE\s*VENTI',
    '매머드커피': r'매머드|MAMMOTH',
    '텐퍼센트커피': r'텐퍼센트|10\s*PERCENT'
}

# %%
def extract_brand(name):
    name = str(name).upper()
    for brand, pattern in brand_patterns.items():
        if re.search(pattern, name, flags=re.IGNORECASE):
            return brand
    return '기타커피전문점'

# %%
df_cafe['브랜드명'] = df_cafe['상호명'].apply(extract_brand)
df_cafe.head()
# Out:
#                    상가업소번호      상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 3    MA010120220808205276      칸토빈       음식    비알코올        카페
# 51   MA010120220812914468  빽다방구산역점       음식    비알코올        카페
# 78   MA010120220806903716     맹커피숍       음식    비알코올        카페
# 109  MA010120220802781563       담다       음식    비알코올        카페
# 118  MA010120220802680776       초원       음식    비알코올        카페
#
#                      도로명주소         위도          경도     브랜드명
# 3        서울특별시 강서구 방화동로 30  37.563548  126.810493  기타커피전문점
# 51       서울특별시 은평구 연서로 129  37.610477  126.916688      빽다방
# 78        서울특별시 은평구 불광로 27  37.610773  126.928818  기타커피전문점
# 109  서울특별시 동대문구 왕산로19가길 67  37.581067  127.031631  기타커피전문점
# 118       서울특별시 동대문구 왕산로 9  37.576284  127.024498  기타커피전문점

# %%
brand_counts = df_cafe['브랜드명'].value_counts().reset_index()
brand_counts
# Out:
#        브랜드명  count
# 0   기타커피전문점  21067
# 1      메가커피    977
# 2     컴포즈커피    457
# 3     매머드커피    450
# 4       이디야    436
# 5    투썸플레이스    376
# 6       빽다방    372
# 7       커피빈    239
# 8       더벤티    158
# 9       할리스    115
# 10   텐퍼센트커피     86
# 11     탐앤탐스     65
# 12     파스쿠찌     47

# %%
df_cafe[df_cafe['상호명'].str.contains("메가")]
# Out:
#                       상가업소번호                상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 1914    MA010120220813183823          메가엠지씨커피수유       음식    비알코올        카페
# 3066    MA010120220812507366    메가MGC커피상암사보이시티점       음식    비알코올        카페
# 3583    MA010120220809740316       메가엠지씨커피휘경주공점       음식    비알코올        카페
# 3810    MA010120220803674019        메가엠지씨커피강동역점       음식    비알코올        카페
# 4819    MA010120220803331542       메가엠지씨커피신용산역점       음식    비알코올        카페
# ...                      ...                ...      ...      ...      ...
# 536553  MA0106202602A1091637   메가엠지씨커피 역삼e편한세상점       음식    비알코올        카페
# 536689  MA0106202602A0210729     메가엠지씨커피 방학빌리지점       음식    비알코올        카페
# 537023  MA0106202602A1405294  메가엠지씨커피 강남솔라티움시티점       음식    비알코올        카페
# 537056  MA0106202602A2096269  메가엠지씨커피 금천시흥유통상가점       음식    비알코올        카페
# 537437  MA0106202601A1360855      메가엠지씨커피 논현동현점       음식    비알코올        카페
#
#                         도로명주소         위도          경도  브랜드명
# 1914        서울특별시 강북구 삼양로 308  37.630912  127.018013  메가커피
# 3066    서울특별시 마포구 월드컵북로54길 17  37.581325  126.888542  메가커피
# 3583    서울특별시 동대문구 사가정로25길 29  37.580149  127.070394  메가커피
# 3810      서울특별시 강동구 천호대로 1107  37.535853  127.135229  메가커피
# 4819     서울특별시 용산구 한강대로 130-3  37.531017  126.969996  메가커피
# ...                       ...        ...         ...   ...
# 536553      서울특별시 강남구 선릉로 325  37.498591  127.051568  메가커피
# 536689     서울특별시 도봉구 시루봉로 222  37.668056  127.034763  메가커피
# 537023   서울특별시 서초구 강남대로53길 12  37.494373  127.027694  메가커피
# 537056      서울특별시 금천구 시흥대로 98  37.442764  126.904015  메가커피
# 537437    서울특별시 강남구 도산대로50길 8  37.521842  127.037319  메가커피
#
# [1002 rows x 9 columns]

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    """두 지점의 위도/경도를 이용해 거리(m)를 계산합니다."""
    R = 6371000  # 지구 반지름(m)
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

# %%
# 함수 테스트: 서울시청과 강남역의 대략적인 거리
sample_distance = haversine_distance(37.5665, 126.9780, 37.4979, 127.0276)
print(f'서울시청 ~ 강남역 거리: {sample_distance/1000:.2f}km')
# Out:
# 서울시청 ~ 강남역 거리: 8.79km

# %% [markdown]
# # 각 커피 전문점에서 가장 가까운 스타벅스를 찾는 함수 만들기
# 1. 모든 커피 전문점 순회
# 2. 각 커피 전문점과 모든 스타벅스간의 거리 계산
# 3. 최솟값 추출
#
# - `상가업소번호`, `상호명`, `상권업종대분류명`, `상권업종중분류명`, `상권업종소분류명`, `도로명주소`, `위도`, `경도`, `브랜드명`, `가장가까운스타벅스`, `스타벅스까지거리_m`

# %%
df_cafe['브랜드명'].value_counts()
# Out:
# 브랜드명
# 기타커피전문점    21067
# 메가커피         977
# 컴포즈커피        457
# 매머드커피        450
# 이디야          436
# 투썸플레이스       376
# 빽다방          372
# 커피빈          239
# 더벤티          158
# 할리스          115
# 텐퍼센트커피        86
# 탐앤탐스          65
# 파스쿠찌          47
# Name: count, dtype: int64

# %%
df_cafe.columns
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '위도',
#        '경도', '브랜드명'],
#       dtype='str')

# %%
df_starbucks
# Out:
#        스타벅스지점명                                 스타벅스주소     스타벅스위도      스타벅스경도
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 687      면목역                  서울특별시 중랑구 면목로 403 (면목동)  37.587880  127.087609
# 688       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 689      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 690      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 691      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [692 rows x 4 columns]

# %%
def find_near_starbucks_from_etc_cafe(etc_cafe_df, df_starbucks):
    """
    새로운 df를 만들어서 반환

    etc_cafe_df: 브랜드명이 `기타커피전문점`
    df_starbucks: [스타벅스지점명, 스타벅스주소, 스타벅스위도, 스타벅스경도]

    return:
    df: [상가업소번호, 상호명, 상권업종대분류명, 상권업종중분류명, 상권업종소분류명, 도로명주소, 위도, 경도, 브랜드명, 가장가까운스타벅스, 스타벅스까지거리_m]
    """
    result = etc_cafe_df.copy()

    # etc에서 최소거리 지점명과 그 거리 뽑기
    result[['가장가까운스타벅스', '스타벅스까지거리_m']] = result.apply(
        lambda row: pd.Series(min(
            (
                {
                    '가장가까운스타벅스': starbucks['스타벅스지점명'],
                    '스타벅스까지거리_m': haversine_distance(
                        row['위도'],
                        row['경도'],
                        starbucks['스타벅스위도'],
                        starbucks['스타벅스경도']
                    )
                }
                for _, starbucks in df_starbucks.iterrows()
            ),
            key=lambda x: x['스타벅스까지거리_m']
        )),
        axis=1
    )

    return result

"""
row: min([
            (starbucks['스타벅스지점명'], haversine_distance(row['위도'], row['경도'], starbucks['스타벅스위도'], starbucks['스타벅스경도']))
            for starbucks
            in df_starbucks
        ]),
"""
"""
# row를 df_starbucks의 apply를 이용해서 최솟값 구한 후 추가해주기
        lambda row: df_starbucks.apply(
            lambda star_row: haversine_distance(row['위도'], row['경도'], star_row['스타벅스위도'], star_row['스타벅스경도']),
            axis=1
        )
"""
# Out:
# "\n# row를 df_starbucks의 apply를 이용해서 최솟값 구한 후 추가해주기\n        lambda row: df_starbucks.apply(\n            lambda star_row: haversine_distance(row['위도'], row['경도'], star_row['스타벅스위도'], star_row['스타벅스경도']),\n            axis=1\n        )\n"

# %%
find_near_starbucks_from_etc_cafe(df_cafe[df_cafe["브랜드명"] == "기타커피전문점"], df_starbucks)
# Out:
#                       상가업소번호            상호명 상권업종대분류명 상권업종중분류명    상권업종소분류명  \
# 3       MA010120220808205276            칸토빈       음식    비알코올           카페
# 78      MA010120220806903716           맹커피숍       음식    비알코올           카페
# 109     MA010120220802781563             담다       음식    비알코올           카페
# 118     MA010120220802680776             초원       음식    비알코올           카페
# 149     MA010120220803636048            아인스       음식    비알코올           카페
# ...                      ...            ...      ...      ...         ...
# 537395  MA0106202601A0490135     커피앳웍스 센터원점       음식    비알코올           카페
# 537418  MA0106202601A1726066  지온 Zion 스터디카페   예술·스포츠  도서관·사적지  독서실/스터디 카페
# 537425  MA0106202601A2192126   메이 베이크 커피베이킹       음식    비알코올           카페
# 537428  MA0106202601A1215762       이룬 스터디카페   예술·스포츠  도서관·사적지  독서실/스터디 카페
# 537444  MA0106202601A1372250         올드 캐스크       소매    음료 소매      우유 소매업
#
#                         도로명주소         위도          경도     브랜드명  가장가까운스타벅스  \
# 3           서울특별시 강서구 방화동로 30  37.563548  126.810493  기타커피전문점      송정역
# 78           서울특별시 은평구 불광로 27  37.610773  126.928818  기타커피전문점  불광역8번출구
# 109     서울특별시 동대문구 왕산로19가길 67  37.581067  127.031631  기타커피전문점       고대
# 118          서울특별시 동대문구 왕산로 9  37.576284  127.024498  기타커피전문점     신설동역
# 149         서울특별시 동대문구 왕산로 28  37.576401  127.026807  기타커피전문점     신설동역
# ...                       ...        ...         ...      ...        ...
# 537395      서울특별시 중구 을지로5길 26  37.567393  126.985149  기타커피전문점  을지로삼화타워
# 537418     서울특별시 동대문구 전농로 211  37.583077  127.053539  기타커피전문점    청량리역사
# 537425   서울특별시 서초구 서초대로25길 90  37.491646  126.992175  기타커피전문점       방배
# 537428     서울특별시 용산구 두텁바위로 43  37.545903  126.976972  기타커피전문점    숙대입구역
# 537444    서울특별시 마포구 월드컵로20길 5  37.557610  126.909232  기타커피전문점      망원역
#
#         스타벅스까지거리_m
# 3       291.208992
# 78      135.506136
# 109     365.041233
# 118     104.377790
# 149     116.871465
# ...            ...
# 537395   67.069167
# 537418  519.768337
# 537425  150.978664
# 537428  477.710113
# 537444  233.568476
#
# [21067 rows x 11 columns]

# %%
# 모든 커피전문점과 모든 스타벅스의 거리를 비교한 뒤, 가장 가까운 스타벅스의 거리를 구함
def add_nearest_starbucks(cafe_df, starbucks_df, chunk_size=2000):
    cafe_df = cafe_df.copy().reset_index(drop=True)
    starbucks_df = starbucks_df.copy().reset_index(drop=True)

    sb_lat = starbucks_df['스타벅스위도'].to_numpy()
    sb_lon = starbucks_df['스타벅스경도'].to_numpy()
    sb_name = starbucks_df['스타벅스지점명'].to_numpy()

    nearest_distances = []
    nearest_names = []

    for start in range(0, len(cafe_df), chunk_size):
        end = min(start + chunk_size, len(cafe_df))
        chunk = cafe_df.iloc[start:end]

        # 1차원 배열을 2차원 세로 배열로 바꿈
        # [37.1 37.2 37.3] -> [[37.1] [37.2] [37.3]]
        cafe_lat = chunk['위도'].to_numpy()[:, None]
        cafe_lon = chunk['경도'].to_numpy()[:, None]

        """
                    스타벅스1       스타벅스2       스타벅스3       스타벅스4 ...
            카페1     1200m          2500m            50m           430m
            카페2       ..             ..             ..             ..
            카페3
            ...
        """
        dist_matrix = haversine_distance(cafe_lat, cafe_lon, sb_lat[None, :], sb_lon[None, :])
        min_idx = dist_matrix.argmin(axis=1)
        min_dist = dist_matrix.min(axis=1)
        nearest_distances.extend(min_dist)
        nearest_names.extend(sb_name[min_idx])
        print(f'{end:,}/{len(cafe_df):,}개 처리 완료' )

    cafe_df['가장가까운스타벅스'] = nearest_names
    cafe_df['스타벅스까지거리_m'] = nearest_distances
    return cafe_df

# %% [markdown]
# ### 거리 구간별 분석
# - 0 ~ 50m: 거의 바로 옆
# - 50 ~ 100m: 매우 가까움m
# - 100 ~ 300m: 도보권
# - 300 ~ 500m: 인근 상권
# - 500 ~ 1km: 같은 생활권
# - 1km 이상: 상대적으로 먼거리

# %%
df_cafe_dist = add_nearest_starbucks(df_cafe, df_starbucks)
# Out:
# 2,000/24,845개 처리 완료
# 4,000/24,845개 처리 완료
# 6,000/24,845개 처리 완료
# 8,000/24,845개 처리 완료
# 10,000/24,845개 처리 완료
# 12,000/24,845개 처리 완료
# 14,000/24,845개 처리 완료
# 16,000/24,845개 처리 완료
# 18,000/24,845개 처리 완료
# 20,000/24,845개 처리 완료
# 22,000/24,845개 처리 완료
# 24,000/24,845개 처리 완료
# 24,845/24,845개 처리 완료

# %%
bins = [0, 50, 100, 300, 500, 1000, np.inf]
labels = ['0 ~ 50m', '50 ~ 100m', '100 ~ 300m', '300 ~ 500m', '500 ~ 1km', '1km 이상']

df_cafe_dist['거리구간'] = pd.cut(
    df_cafe_dist['스타벅스까지거리_m'], bins=bins, labels=labels, include_lowest=True
)

# %%
distance_summary = (df_cafe_dist['거리구간'].value_counts().reindex(labels).reset_index())
distance_summary.columns = ['거리구간', '카페수']
distance_summary['비율(%)'] = distance_summary['카페수'] / distance_summary['카페수'].sum() * 100
distance_summary
# Out:
#          거리구간    카페수      비율(%)
# 0     0 ~ 50m   1700   6.842423
# 1   50 ~ 100m   2846  11.455021
# 2  100 ~ 300m  10252  41.263836
# 3  300 ~ 500m   5080  20.446770
# 4   500 ~ 1km   4246  17.089958
# 5      1km 이상    721   2.901992

# %%
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=distance_summary, x='거리구간', y='비율(%)')
plt.title('스타벅스 기준 거리 구간별 커피전문점 비율')
plt.xlabel('스타벅스까지 거리')
plt.ylabel('비율(%)')
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'distance_bucket_ratio.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
radius_list = [50, 100, 300, 500, 1000]

radius_summary = []
for radius in radius_list:
    count = (df_cafe_dist['스타벅스까지거리_m'] <= radius).sum()
    ratio = count / len(df_cafe_dist) * 100
    radius_summary.append({
        '반경': f'{radius}m 이내',
        '반경_m': radius,
        '카페수': count,
        '비율(%)': ratio
    })

radius_summary = pd.DataFrame(radius_summary)

# %%
plt.figure(figsize=(9, 5))
sns.lineplot(data=radius_summary, x='반경_m', y='비율(%)', marker='o')
plt.title('스타벅스 반경별 커피전문점 누적 비율')
plt.xlabel('스타벅스 반경(m)')
plt.ylabel('누적 비율(%)')
plt.xticks(radius_list)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'radius_cumulative_ratio.png', dpi=150, bbox_inches='tight')
plt.show()
